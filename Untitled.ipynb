# %%
import pandas as pd
df = pd.read_csv("hospitals_plus_depts.csv")

# %%
df= df[["Place_1","Place_2","name","lat","long","rating","vicinity","Place_id","Open_Status","Mobile Number","Dept","no_of_beds"]]
df=df.rename(columns={"name": "Name", "lat": "Latitude","long":"Longitude","rating":"Rating","vicinity":"Vicinity","Mobile Number":"Phone_number"},inplace=False)
df
# Out:
#      Place_1  Place_2                                   Name   Latitude  \
# 0        NaN      NaN  SREE NETHRA ENT AND EYE CARE HOSPITAL  14.674182
# 1        NaN      NaN                         AASHA HOSPITAL  14.680907
# 2        NaN      NaN                        KK NURSING HOME  14.679016
# 3        NaN      NaN                      SPANDANA HOSPITAL  14.407830
# 4        NaN      NaN       Pavani Multi Speciality Hospital  14.672798
# ..       ...      ...                                    ...        ...
# 541      NaN      NaN                        RAVI NETRALAYAM  14.752309
# 542      NaN      NaN                          SREE HOSPITAL  14.463310
# 543      NaN      NaN  Shree Madan Multi Speciality Hospital  14.750360
# 544      NaN      NaN              ABHILASH NETRA VYDYA SALA  14.754722
# 545      NaN      NaN           Ramakrishna Mission Hospital  27.137060
#
#      Longitude  Rating                                       Vicinity  \
# ...

# %%
df.to_csv("hospitals_plus_depts.csv",index=False)
